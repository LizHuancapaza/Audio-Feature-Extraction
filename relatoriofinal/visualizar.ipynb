# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
def plotnormal():
    return plt.plot(np.random.randn(1000), np.random.randn(1000), 'o', alpha=0.9)
plotnormal()

# %%
disenhe uma ciosa legal

# %run non_existent_file

# %% [markdown]
# acho que nao deu certo meu mardown aperto esc  y depois m

# %% [markdown]
# OQUE FOI

# %% [markdown]
# ENTAO FICA ASI PARA TEXTO OU MARDOWN------ ESC---M----CTRL ENTER--- SHIFT ENTER
